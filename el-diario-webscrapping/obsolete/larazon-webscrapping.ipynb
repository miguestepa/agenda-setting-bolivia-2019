# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
import time

# %%
# Classic combo to access an URL and get it nicely.
URL = 'https://www.eldiario.net/noticias/2019/2019_11/nt191101/politica.php?n=45&-morales-pide-pausa-los-civicos-rechazan-y-exigen-su-renuncia'
soup = BeautifulSoup(page.content, 'html.parser')

# The part where the desired info is:
main_body = soup.find(id='col_a')

#print(results.prettify())

#Accesing the main body of the article
main_body_parts = []
for part in main_body.select('div'): 
    #print('---------------------')
    #print(elem)
    main_body_parts.append(part)

#print(divs[0])

# Here is my beloved text
main_text = main_body_parts[0].find('div', class_ ="nota_txt")
texto_completo = main_text.find_all('p')

# Lets get rid of everything but the text itsef.
phrases = []
for fragmento in texto_completo:
    phrases.append(fragmento.getText())
    
phrases
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-203-8c1ccab099cc> in <module>
#      19 # Here is my beloved text
#      20 main_text = main_body_parts[0].find('div', class_ ="nota_txt")
# ---> 21 texto_completo = main_text.find_all('p')
#      22
#      23 # Lets get rid of everything but the text itsef.
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
#This cell split the different phrases in words.

article_words = []

for phrase in phrases:
    article_words.append(phrase.split())

#super fast way to flatten a nested list
article_words = [x for y in article_words for x in y]
len (article_words)
# Out:
# 752

# %%
#article_words = np.array(article_words)
#article_words.flatten()

# %%
# Classic combo to access an URL and get it nicely.
URL = 'https://www.eldiario.net/noticias/2019/2019_11/nt191120/i_politica.php'
page = requests.get(URL)
soup = BeautifulSoup(page.content, 'html.parser')


# The part where the desired info is:
main_body = soup.find(id='col_a')

#print(main_body.prettify())

#once we have the main body, this is the way to get the link.
links_with_text=[]
for a in main_body.find_all('a', href=True): 
    if a.text: 
        links_with_text.append(a['href'])

links_with_text[0]
# Out:
# 'politica.php?n=21&-iglesia-ue-y-politicos-gestionan-convocatoria-a-elecciones'

# %%
URL = 'https://www.eldiario.net/noticias/2019/2019_11/nt191120/i_politica.php'
soup = BeautifulSoup(page.content, 'html.parser')
for a in soup.find_all('a', href=True):
    print ("Found the URL:", a['href'])
# Out:
# Found the URL: i_politica.php
# Found the URL: https://www.facebook.com/pages/El-Diario-Bolivia/211315185622429
# Found the URL: https://twitter.com/eldiario_net
# Found the URL: https://rss.eldiario.net/rss.php
# Found the URL: ../../../../promociones/
# Found the URL: mailto:webmaster@eldiario.net
# Found the URL: index.php
# Found the URL:
# Found the URL: i_editorial.php
# Found the URL: i_opinion.php
# Found the URL: i_politica.php
# Found the URL: i_economia.php
# Found the URL: i_sociedad.php
# Found the URL: i_nacional.php
# Found the URL: i_cultural.php
# Found the URL: i_deportes.php
# Found the URL: i_internacional.php
# Found the URL: i_sociales.php
# Found the URL: ../../../../revistas/
# Found the URL: ../../../../noticias/2019/2019_12/nt191230/i_ciencia.php
# Found the URL: ../../../../noticias/2019/2019_12/nt191231/i_nuevoshorizontes.php
# Found the URL: ../../../../noticias/2020/2020_01/nt200101/i_cinemundo.php
# Found the URL: ../../../../noticias/2019/2019_12/nt191219/i_femenina.php
# Found the URL: ../../../../noticias/2019/2019_12/nt191229/i_laguia.php
# Found the URL: ../../../../noticias/2019/2019_12/nt191229/i_lustra.php
# Found the URL: ../../../../noticias/2018/2018_09/nt180927/i_agraria.php
# Found the URL: ../../../../noticias/2019/2019_12/nt191230/i_metrocuadrado.php
# Found the URL:
# Found the URL: ../../../../clasificados/
# Found the URL: ../../../../clasificados/clasificados.php?c=1&d=
# Found the URL: ../../../../clasificados/clasificados.php?c=2&d=
# Found the URL: ../../../../clasificados/clasificados.php?c=3&d=
# Found the URL: ../../../../clasificados/clasificados.php?c=4&d=
# Found the URL: ../../../../clasificados/clasificados_a.php?d=
# Found the URL: ../../../../clasificados/clasificados.php?c=5&d=
# Found the URL: ../../../../especiales/?d=
# Found the URL: ../../../../recuadros/?d=
# Found the URL: https://www.eldiario.net/diario/
# Found the URL: ../../../../agencias/
# Found the URL: ../../../../carrera/
# Found the URL: #
# Found the URL: #
# Found the URL: #
# Found the URL: https://twitter.com/share
# Found the URL: f_2019-11-20_17.jpg
# Found the URL: f_2019-11-20_19.jpg
# Found the URL: politica.php?n=21&-iglesia-ue-y-politicos-gestionan-convocatoria-a-elecciones
# Found the URL: politica.php?n=22&-evo-morales-descarta-desmovilizar-a-sus-bases
# Found the URL: politica.php?n=23&-cancilleria-dio-salvoconductos-a-masistas-para-que-salgan-del-pais
# Found the URL: politica.php?n=24&-piden-al-tcp-revisar-sentencias-que-permiten-repostulaciones
# Found the URL: politica.php?n=25&-diputados-sesiona-hoy-para-tratar-renuncias
# Found the URL: #
# Found the URL: #0
# Found the URL: #1
# Found the URL: #2
# Found the URL: #3
# Found the URL: #4
# Found the URL: #5
# Found the URL: #6
# Found the URL: #7
# Found the URL: #
# Found the URL: ../../../2019/2019_11/nt191118/i_ciencia.php
# Found the URL: ../../../2019/2019_11/nt191118/i_ciencia.php
# Found the URL: ../../../2019/2019_11/nt191118/ciencia.php?n=1&-el-xiaomi-mi-note-10-llegara-con-un-nuevo-sensor-de-huellas
# Found the URL: ../../../2019/2019_11/nt191118/ciencia.php?n=3&-acerca-de-la-camara-del-iphone-11-pro
# Found the URL: ../../../2019/2019_11/nt191118/ciencia.php?n=2&-el-huawei-ability-gallery-impulsa-el-crecimiento-del-hms
# Found the URL: ../../../2019/2019_11/nt191118/ciencia.php?n=12&-brother-td-4420tn-impresora-termica
# Found the URL: ../../../2019/2019_11/nt191118/ciencia.php?n=6&-como-puedo-saber-si-alguien-entro-a-mi-cuenta-de-instagram
# Found the URL: ../../../2019/2019_11/nt191118/ciencia.php?n=1&-el-xiaomi-mi-note-10-llegara-con-un-nuevo-sensor-de-huellas
# Found the URL: ../../../2019/2019_11/nt191105/i_nuevoshorizontes.php
# Found the URL: ../../../2019/2019_11/nt191105/i_nuevoshorizontes.php
# Found the URL: ../../../2019/2019_11/nt191105/nuevoshorizontes.php?n=2&-dia-mundial-de-la-ciencia-para-la-paz-y-el-desarrollo
# Found the URL: ../../../2019/2019_11/nt191105/nuevoshorizontes.php?n=4&-la-electrodinamica
# Found the URL: ../../../2019/2019_11/nt191105/nuevoshorizontes.php?n=1&-braveup
# Found the URL: ../../../2019/2019_11/nt191105/nuevoshorizontes.php?n=7&-nitrilos
# Found the URL: ../../../2019/2019_11/nt191105/nuevoshorizontes.php?n=5&-los-deportes
# Found the URL: ../../../2019/2019_11/nt191105/nuevoshorizontes.php?n=2&-dia-mundial-de-la-ciencia-para-la-paz-y-el-desarrollo
# Found the URL: ../../../2019/2019_11/nt191106/i_cinemundo.php
# Found the URL: ../../../2019/2019_11/nt191106/i_cinemundo.php
# Found the URL: ../../../2019/2019_11/nt191106/cinemundo.php?n=3&-dc-continua-expandiendo-su-universo-con-aves-de-presa-y-la-fabulosa-e
# Found the URL: ../../../2019/2019_11/nt191106/cinemundo.php?n=4&-terminator-y-sarah-connor-retornan-mas-maduros-pero-igual-de-letales
# Found the URL: ../../../2019/2019_11/nt191106/cinemundo.php?n=5&-dia-de-muertos-la-pelicula-que-atraso-su-estreno-por-culpa-de-coco
# Found the URL: ../../../2019/2019_11/nt191106/cinemundo.php?n=6&-creadores-de-juego-de-tronos-abandonan-el-proyecto-star-wars
# Found the URL: ../../../2019/2019_11/nt191106/cinemundo.php?n=7&-aumentan-las-quejas-contra-turistas-que-se-toman-fotos-en-las-escaler
# Found the URL: ../../../2019/2019_11/nt191106/cinemundo.php?n=3&-dc-continua-expandiendo-su-universo-con-aves-de-presa-y-la-fabulosa-e
# Found the URL: ../../../2019/2019_11/nt191107/i_femenina.php
# Found the URL: ../../../2019/2019_11/nt191107/i_femenina.php
# Found the URL: ../../../2019/2019_11/nt191107/femenina.php?n=3&-gala-mtv-emas-2019
# Found the URL: ../../../2019/2019_11/nt191107/femenina.php?n=4&-amor-de-tres-el-ella-y
# Found the URL: ../../../2019/2019_11/nt191107/femenina.php?n=5&-mi-primera-consulta-ginecologica
# Found the URL: ../../../2019/2019_11/nt191107/femenina.php?n=6&-ventajas-y-desventajas-de-ser-hijo-unico
# Found the URL: ../../../2019/2019_11/nt191107/femenina.php?n=1&-jugo-manianero-para-adelgazar
# Found the URL: ../../../2019/2019_11/nt191107/femenina.php?n=3&-gala-mtv-emas-2019
# Found the URL: ../../../2019/2019_11/nt191110/i_laguia.php
# Found the URL: ../../../2019/2019_11/nt191110/i_laguia.php
# Found the URL: ../../../2019/2019_11/nt191110/laguia.php?n=9&-rumba-7-la-leyenda-continua
# Found the URL: ../../../2019/2019_11/nt191110/laguia.php?n=10&-palomitay-llega-a-la-pantalla-grande
# Found the URL: ../../../2019/2019_11/nt191110/laguia.php?n=11&-fabiana-alvarez
# Found the URL: ../../../2019/2019_11/nt191110/laguia.php?n=12&-homenaje-al-patron-de-la-cumbia-pitty-zapata
# Found the URL: ../../../2019/2019_11/nt191110/laguia.php?n=13&-melvy-lopez
# Found the URL: ../../../2019/2019_11/nt191110/laguia.php?n=9&-rumba-7-la-leyenda-continua
# Found the URL: ../../../2019/2019_11/nt191110/i_lustra.php
# Found the URL: ../../../2019/2019_11/nt191110/lustra.php?n=7&-pagina-8
# Found the URL: ../../../2019/2019_11/nt191110/lustra.php?n=6&-pagina-7
# Found the URL: ../../../2019/2019_11/nt191110/lustra.php?n=5&-pagina-6
# Found the URL: ../../../2019/2019_11/nt191110/lustra.php?n=4&-pagina-4
# Found the URL: ../../../2019/2019_11/nt191110/lustra.php?n=3&-pagina-3
# Found the URL: ../../../2019/2019_11/nt191110/lustra.php?n=7&-pagina-8
# Found the URL: ../../../2018/2018_09/nt180927/i_agraria.php
# Found the URL: ../../../2018/2018_09/nt180927/i_agraria.php
# Found the URL: ../../../2018/2018_09/nt180927/agraria.php?n=77&-produccion-de-trigo-llego-al-30-por-ciento-frente-a-la-demanda-nacion
# Found the URL: ../../../2018/2018_09/nt180927/agraria.php?n=78&-con-rotacion-de-cultivos-se-sembro-trigo-pero-la-sequia-mermo-33-de-l
# Found the URL: ../../../2018/2018_09/nt180927/agraria.php?n=80&-agricultores-de-okinawa-estimaron-promedio-de-1-7-toneladas-de-trigo-
# Found the URL: ../../../2018/2018_09/nt180927/agraria.php?n=81&-municipio-de-la-paz-ya-cuenta-con-una-ley-de-fomento-a-los-huertos-ur
# Found the URL: ../../../2018/2018_09/nt180927/agraria.php?n=79&-productores-de-viacha-mostraron-su-potencial-agropecuario-en-la-xiii-
# Found the URL: ../../../2018/2018_09/nt180927/agraria.php?n=77&-produccion-de-trigo-llego-al-30-por-ciento-frente-a-la-demanda-nacion
# Found the URL: ../../../2019/2019_10/nt191028/i_metrocuadrado.php
# Found the URL: ../../../2019/2019_10/nt191028/i_metrocuadrado.php
# Found the URL: ../../../2019/2019_10/nt191028/metrocuadrado.php?n=63&-fomentando-huertos-vecinales-escolares-y-familiares
# Found the URL: ../../../2019/2019_10/nt191028/metrocuadrado.php?n=64&-calculo-del-costo-indirecto-de-la-obra
# Found the URL: ../../../2019/2019_10/nt191028/metrocuadrado.php?n=65&-la-hidro-arquitectura
# Found the URL: ../../../2019/2019_10/nt191028/metrocuadrado.php?n=62&-y-esto-que-paso-con-el-puente-de-la-via-ferrea
# Found the URL: ../../../2019/2019_10/nt191028/metrocuadrado.php?n=63&-fomentando-huertos-vecinales-escolares-y-familiares
# Found the URL: t_portada1.jpg
# Found the URL: s_portada1.jpg
# Found the URL: p_portada1.pdf
# Found the URL: ../../../../hemeroteca/
# Found the URL: mailto:redinfo@eldiario.net

# %% [markdown]
# # LOOP FOR TO SCRAP THE NEWS

# %% [markdown]
# This cell will execute the code for each day

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
import time

article_name = []
article_date = []
article_words = []
article_len = []

for month in range(11,12):
    for day in range (1,30):
        
        #this defines the changing name of each article
        name = 'i_politica.php'
        
        if day > 9:
            URL = f'https://www.eldiario.net/noticias/2019/2019_{str(month)}/nt19{str(month)}{str(day)}/{name}'
            #print(URL)
        else:
            URL = f'https://www.eldiario.net/noticias/2019/2019_{str(month)}/nt19{str(month)}0{str(day)}/{name}'
            #print(URL)
            
        #------------------------------------------------
        #--------------- FIRST PART ---------------------
        #------------------------------------------------
        
        #This part of the code retrieves the links of the news (1 for now).
        
        #The first request
        page = requests.get(URL)
        soup = BeautifulSoup(page.content, 'html.parser')

        #The part where the desired info is:
        main_body = soup.find(id='col_a')

        #print(main_body.prettify())

        #once we have the main body, this is the way to get the link.
        links_with_text=[]
        for a in main_body.find_all('a', href=True): 
            if a.text: 
                links_with_text.append(a['href'])

        #Now, the 'name' will change and will be the link of the new we want to analyze.
        name = str(links_with_text[0])
        
        #------------------------------------------------
        #--------------- SECOND PART --------------------
        #------------------------------------------------
        
        #This part analyze the given new
        if day >= 10:
            URL = f'https://www.eldiario.net/noticias/2019/2019_{str(month)}/nt19{str(month)}{str(day)}/{name}'
            #print(URL)
        elif day < 10:
            URL = f'https://www.eldiario.net/noticias/2019/2019_{str(month)}/nt19{str(month)}0{str(day)}/{name}'
            #print(URL)      
        
        #This part analyze the given new
        URL = f'https://www.eldiario.net/noticias/2019/2019_{str(month)}/nt19{str(month)}{str(day)}/{name}'
        page = requests.get(URL)
        soup = BeautifulSoup(page.content, 'html.parser')

        # The part where the desired info is:
        main_body = soup.find(id='col_a')

        #print(results.prettify())

        #Accesing the main body of the article
        main_body_parts = []
        for part in main_body.select('div'): 
            #print('---------------------')
            #print(elem)
            main_body_parts.append(part)

        #print(divs[0])

        # Here is my beloved text
        main_text = main_body_parts[0].find('div', class_ ="nota_txt")
        texto_completo = main_text.find_all('p')

        #Lets get rid of everything but the text itsef.
        #It will be store in 'phrases'.
        phrases = []
        for fragmento in texto_completo:
            phrases.append(fragmento.getText())    
            
        #--------------------    
        
        # In this part of the code, the phrases are split and store
        # along with more info, such as date or number of words.
        list_words = []

        for phrase in phrases:
            list_words.append(phrase.split())

        #super fast way to flatten a nested list
        flatten_words = [x for y in article_words for x in y]
        
        #time to add the info to different lists
        article_name.append(str(name))
        article_date.append(f'2019/{str(month)}/{str(day)}')
        article_words.append(flatten_words)
        article_len.append(len(flatten_words))
        article_URL.append(URL)   
             
        time.sleep(1)
        
#------------------------------------------------
#--------------- PANDAS PART --------------------
#------------------------------------------------
                            
df = pd.DataFrame(list(zip(article_name, article_date,article_words,article_len,article_URL)), 
               columns =['article_name', 'article_date','article_words','article_len','article_URL'])
                            
df.to_csv('larazon.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-201-ae7f8fb30e66> in <module>
#      72         #Accesing the main body of the article
#      73         main_body_parts = []
# ---> 74         for part in main_body.select('div'):
#      75             #print('---------------------')
#      76             #print(elem)
#
# AttributeError: 'NoneType' object has no attribute 'select'

# %%
for month in range(11,12):
    for day in range (1,30):
        
        #this defines the changing name of each article
        name = 'i_politica.php'
        
        if day >= 10:
            URL = f'https://www.eldiario.net/noticias/2019/2019_{str(month)}/nt19{str(month)}{str(day)}/{name}'
            #print(URL)
        elif day < 10:
            URL = f'https://www.eldiario.net/noticias/2019/2019_{str(month)}/nt19{str(month)}0{str(day)}/{name}'
            #print(URL)
            
        #------------------------------------------------
        #--------------- FIRST PART ---------------------
        #------------------------------------------------
        
        #This part of the code retrieves the links of the news (1 for now).
        
        #The first request
        page = requests.get(URL)
        soup = BeautifulSoup(page.content, 'html.parser')

        #The part where the desired info is:
        main_body = soup.find(id='col_a')

        #print(main_body.prettify())

        #once we have the main body, this is the way to get the link.
        links_with_text=[]
        for a in main_body.find_all('a', href=True): 
            if a.text: 
                links_with_text.append(a['href'])

        #Now, the 'name' will change and will be the link of the new we want to analyze.
        name = str(links_with_text[0])
        
        #------------------------------------------------
        #--------------- SECOND PART --------------------
        #------------------------------------------------
            
        #This part analyze the given new
        if day >= 10:
            URL = f'https://www.eldiario.net/noticias/2019/2019_{str(month)}/nt19{str(month)}{str(day)}/{name}'
            #print(URL)
        elif day < 10:
            URL = f'https://www.eldiario.net/noticias/2019/2019_{str(month)}/nt19{str(month)}0{str(day)}/{name}'
            #print(URL)
        print(URL)
# Out:
# https://www.eldiario.net/noticias/2019/2019_11/nt191101/politica.php?n=45&-morales-pide-pausa-los-civicos-rechazan-y-exigen-su-renuncia
# https://www.eldiario.net/noticias/2019/2019_11/nt191102/politica.php?n=53&-se-fractura-mision-de-oea-por-renuncia-de-su-coordinador
# https://www.eldiario.net/noticias/2019/2019_11/nt191103/politica.php?n=20&-piden-cumbre-nacional-para-definir-estrategias
# https://www.eldiario.net/noticias/2019/2019_11/nt191104/politica.php?n=77&-camacho-a-morales-vamos-a-sacarlo-sin-una-sola-bala
# https://www.eldiario.net/noticias/2019/2019_11/nt191105/politica.php?n=64&-civicos-deciden-cerrar-fronteras-e-instituciones
