# %%
import pandas as pd
import numpy as np

# %%
emotion_dict = pd.read_csv('Spanish-es-NRC-Emotion-Intensity-Lexicon-v1.txt', sep = '\t', engine='python')
articles_larazon = pd.read_csv('..\larazon-webscrapping\larazon.csv')

# %%
df_emotion = pd.DataFrame(emotion_dict)
df_articles = pd.DataFrame(articles_larazon)

# %%
print (df_emotion.emotion.unique())
df_emotion.head(10)
# Out:
# ['anger' 'anticipation' 'disgust' 'fear' 'joy' 'sadness' 'surprise'
#  'trust']
#          word     Spanish-es emotion  emotion-intensity-score
# 0    outraged      indignado   anger                    0.964
# 1   brutality     brutalidad   anger                    0.959
# 2      hatred           odio   anger                    0.953
# 3     hateful         odioso   anger                    0.940
# 4   terrorize    aterrorizar   anger                    0.939
# 5   violently  violentamente   anger                    0.938
# 6  infuriated     enfurecido   anger                    0.938
# 7     furious        furioso   anger                    0.929
# 8     enraged     enfurecido   anger                    0.927
# 9   furiously   furiosamente   anger                    0.927

# %%
df_articles
# Out:
#     Unnamed: 0                                       article_name  \
# 0            0  politica.php?n=45&-morales-pide-pausa-los-civi...
# 1            1  sociedad.php?n=15&-ministerio-publico-no-escla...
# 2            2  nacional.php?n=48&-afines-al-gobierno-agredier...
# 3            3  politica.php?n=53&-se-fractura-mision-de-oea-p...
# 4            4  sociedad.php?n=19&-6-aprehendidos-por-muerte-d...
# 5            5  nacional.php?n=16&-bloqueos-se-mantuvieron-en-...
# 6            6  politica.php?n=20&-piden-cumbre-nacional-para-...
# 7            7  sociedad.php?n=27&-sujeto-de-la-escopeta-dio-p...
# 8            8  nacional.php?n=46&-dinamitazos-y-violencia-des...
# 9            9  politica.php?n=77&-camacho-a-morales-vamos-a-s...
# 10          10  sociedad.php?n=29&-carlos-romero-asegura-que-h...
# 11          11  nacional.php?n=37&-iglesia-preocupada-por-crec...
#
#    article_date article_category  \
# 0     2019/11/1         politica
# 1     2019/11/1         sociedad
# 2     2019/11/1         nacional
# 3     2019/11/2         politica
# 4     2019/11/2         sociedad
# 5     2019/11/2         nacional
# 6     2019/11/3         politica
# 7     2019/11/3         sociedad
# 8     2019/11/3         nacional
# 9     2019/11/4         politica
# 10    2019/11/4         sociedad
# 11    2019/11/4         nacional
#
#                                         article_words  article_len  \
# 0   ['Después', 'de', 'dos', 'muertes', 'en', 'el'...          638
# 1   ['En', 'los', 'más', 'de', '13', 'años', 'de',...          887
# 2   ['Al', 'mediodía', 'de', 'ayer', 'un', 'numero...          468
# 3   ['La', 'misión', 'de', 'expertos', 'de', 'la',...          413
# 4   ['El', 'fiscal', 'departamental', 'de', 'Santa...          192
# 5   ['Pese', 'a', 'la', 'festividad', 'de', 'Todos...          304
# 6   ['El', 'analista', 'Iván', 'Arias,', 'señaló',...          723
# 7   ['Wilson', 'Rodríguez', 'Peralta,', 'el', 'suj...          373
# 8   ['Detonaciones', 'de', 'dinamitas', 'causadas'...          568
# 9   ['El', 'presidente', 'del', 'Comité', 'Cívico'...          577
# 10  ['El', 'ministro', 'de', 'Gobierno,', 'Carlos'...          562
# 11  ['La', 'Iglesia', 'Católica', 'advirtió', 'aye...          311
#
#                                           article_URL
# 0   https://www.eldiario.net/noticias/2019/2019_11...
# 1   https://www.eldiario.net/noticias/2019/2019_11...
# 2   https://www.eldiario.net/noticias/2019/2019_11...
# 3   https://www.eldiario.net/noticias/2019/2019_11...
# 4   https://www.eldiario.net/noticias/2019/2019_11...
# 5   https://www.eldiario.net/noticias/2019/2019_11...
# 6   https://www.eldiario.net/noticias/2019/2019_11...
# 7   https://www.eldiario.net/noticias/2019/2019_11...
# 8   https://www.eldiario.net/noticias/2019/2019_11...
# 9   https://www.eldiario.net/noticias/2019/2019_11...
# 10  https://www.eldiario.net/noticias/2019/2019_11...
# 11  https://www.eldiario.net/noticias/2019/2019_11...

# %% [markdown]
# # Getting words from articles

# %%
articles = pd.Series(df_articles['article_words']) 
articles.head(10) 
#print(articles[2])

list_words=[]

for article in articles:

    result = [x.strip(",") for x in article.split("'")]
    result = [x.strip("(.)") for x in result]
    result = [i.lower() for i in result if len(i)>3] 
    list_words.append(result)

list_words[0]
# Out:
# ['después',
#  'muertes',
#  'municipio',
#  'montero',
#  'santa',
#  'cruz',
#  'presidente',
#  'morales',
#  'pidió',
#  'sectores',
#  'movilizados',
#  'población',
#  'cuarto',
#  'intermedio',
#  'protestas',
#  'todos',
#  'santos',
#  'fútbol',
#  'hasta',
#  'tener',
#  'resultados',
#  'auditoría',
#  'realizará',
#  'organización',
#  'estados',
#  'americanos',
#  'cómputo',
#  'oficial',
#  'elecciones',
#  'generales',
#  'pasadas',
#  'cívicos',
#  'país',
#  'rechazaron',
#  'propuesta',
#  'exigen',
#  'renuncia',
#  'advirtieron',
#  'marchas',
#  'paro',
#  'indefinido',
#  'suspenderán',
#  '“pido',
#  'están',
#  'paro',
#  'bloqueo',
#  'levantar',
#  'esas',
#  'medidas',
#  'cuarto',
#  'intermedio',
#  'movilizaciones',
#  'hasta',
#  'delegados',
#  'tres',
#  'países',
#  'concluyan',
#  'informe',
#  'correspondiente',
#  'proceso',
#  'electoral',
#  'movimientos',
#  'sociales',
#  'pedido',
#  'levanten',
#  'bloqueo',
#  'hermanos',
#  'están',
#  'paro',
#  'pequeños',
#  'bloqueos',
#  'ciudades',
#  'levanten',
#  'paro',
#  'empezar',
#  'resolver',
#  'pacificar',
#  'bolivia”',
#  'sostuvo',
#  'mandatario',
#  'conferencia',
#  'prensa',
#  'mandatario',
#  'días',
#  'pasados',
#  'convocó',
#  'aliados',
#  'para',
#  'defiendan',
#  'democracia',
#  'voto',
#  'rural',
#  'advirtió',
#  'cercar',
#  'ciudades',
#  'capitales',
#  'encuentran',
#  'movilizadas',
#  'esto',
#  'rechazado',
#  'diversos',
#  'sectores',
#  'sociales',
#  'derechos',
#  'humanos',
#  'están',
#  'vulnerando',
#  'derechos',
#  'fundamentales',
#  'población',
#  'renuncia',
#  'presidente',
#  'comité',
#  'cívico',
#  'santa',
#  'cruz',
#  'luis',
#  'fernando',
#  'camacho',
#  'rechazó',
#  'petición',
#  'advirtió',
#  'movilizaciones',
#  'continuarán',
#  'otra',
#  'parte',
#  'exigió',
#  'renuncia',
#  'mandatario',
#  'sería',
#  'única',
#  'solución',
#  'para',
#  'pacificar',
#  'país',
#  'además',
#  'pidieron',
#  'convocatoria',
#  'nuevas',
#  'elecciones',
#  'generales',
#  'tribunal',
#  'imparcial',
#  'cuarto',
#  'intermedio',
#  'pero',
#  'presidente',
#  'quiere',
#  'apaciguar',
#  'bolivia',
#  'renuncie',
#  'único',
#  'pedido',
#  'aseguro',
#  'renuncia',
#  'convocatoria',
#  'nuevas',
#  'elecciones',
#  'convocatoria',
#  'elección',
#  'nuevos',
#  'vocales',
#  'tribunal',
#  'electoral',
#  'paro',
#  'levanta',
#  'caso',
#  'contrario',
#  'paro',
#  'continua”',
#  'sentenció',
#  'camacho',
#  'mandatario',
#  'advirtió',
#  'cívicos',
#  'continúan',
#  'medidas',
#  'presión',
#  'pueblo',
#  'puede',
#  'rebelarse',
#  'contra',
#  'ellos',
#  'responsabilizó',
#  'enfrentamientos',
#  'originaron',
#  'entre',
#  'piden',
#  'renuncia',
#  'morales',
#  'respaldan',
#  'victoria',
#  'declaraciones',
#  'surgieron',
#  'después',
#  'postura',
#  'cívico',
#  'cruceño',
#  '“cuidado',
#  'algunos',
#  'dirigentes',
#  'cívicos',
#  'cuidado',
#  'pueblo',
#  'rebele',
#  'tanto',
#  'daño',
#  'están',
#  'haciendo',
#  'solamente',
#  'parte',
#  'económica',
#  'sino',
#  'también',
#  'parte',
#  'confrontación',
#  'momentáneamente',
#  'puede',
#  'engañar',
#  'mentiras',
#  'pueblo',
#  'pero',
#  'después',
#  'elecciones',
#  'reflexiona',
#  'reacciona”',
#  'dijo',
#  'morales',
#  'radio',
#  'panamericana',
#  'respuesta',
#  'presidente',
#  'comité',
#  'cívico',
#  'potosinista',
#  'comcipo',
#  'marco',
#  'pumari',
#  'siete',
#  'instituciones',
#  'cívicas',
#  'convocaron',
#  'paro',
#  'indefinido',
#  'defensa',
#  'voto',
#  'advirtió',
#  'morales',
#  'perdió',
#  'toda',
#  'credibilidad',
#  'tras',
#  'muertes',
#  'ocurridas',
#  'pasado',
#  'miércoles',
#  'población',
#  'montero',
#  'atribuyó',
#  'grupos',
#  'organizados',
#  'movimiento',
#  'socialismo',
#  'haber',
#  'estos',
#  'momentos',
#  'feriados',
#  'fútbol',
#  'como',
#  'menciona',
#  'para',
#  'esta',
#  'movilización',
#  'pare',
#  'tenemos',
#  'objetivo',
#  'único',
#  'cuarto',
#  'intermedio',
#  'vamos',
#  'aceptar',
#  'cívicos',
#  'población',
#  'cuando',
#  'morales',
#  'salga',
#  'palacio',
#  'gobierno',
#  'deje',
#  'poder',
#  'existir',
#  'nuestro',
#  'país”',
#  'afirmó',
#  'acatan',
#  'sectores',
#  'sociales',
#  'afines',
#  'partido',
#  'oficialista',
#  'hicieron',
#  'caso',
#  'petición',
#  'ciudad',
#  'cooperativistas',
#  'mineros',
#  'sectores',
#  'campesinos',
#  'otros',
#  'afines',
#  'continuaron',
#  'causando',
#  'zozobra',
#  'explosión',
#  'dinamitazos',
#  'agresiones',
#  'personal',
#  'médico',
#  'zona',
#  'miraflores',
#  'estos',
#  'sectores',
#  'apostaron',
#  'pocos',
#  'metros',
#  'plaza',
#  'murillo',
#  'donde',
#  'instalaron',
#  'menos',
#  'baños',
#  'portátiles',
#  'intensión',
#  'estos',
#  'sectores',
#  'queden',
#  'resguardando',
#  'denominada',
#  '“casa',
#  'grande',
#  'pueblo”',
#  'candidato',
#  'carlos',
#  'mesa',
#  'pidió',
#  'mandatario',
#  'instruya',
#  'allegados',
#  'suspendan',
#  'movilizaciones',
#  'violentas']

# %% [markdown]
# # Analyze emotions

# %% [markdown]
# This part of the code analize the emotions of each article.
# Then creates a list for each emotion.
# After that, creates a data frame with all the emotions.
# Finally, merges the articles data frame and the emotions data frame.

# %%
emotions_dictionary = dict(zip(df_emotion['Spanish-es'], df_emotion['emotion']))

# %%
from collections import Counter

# %%
list_of_emotions_counter = []

for article in list_words:
    emotional_counter = Counter()
    for word in article:
        if word in list(emotions_dictionary.keys()):
            emotional_counter[emotions_dictionary[word]] += 1
    list_of_emotions_counter.append(emotional_counter)

# %%
list_of_emotions_counter[6]
# Out:
# Counter({'trust': 29,
#          'fear': 10,
#          'surprise': 3,
#          'joy': 1,
#          'sadness': 9,
#          'anger': 1})

# %%
n_trust = []
n_fear = []
n_surprise = []
n_joy = []
n_sadness = []
n_anger = []
n_anticipation = []
n_disgust = []

correlaction_dict = {'trust':n_trust,  
                     'fear':n_fear, 
                     'surprise': n_surprise, 
                     'joy':n_joy, 
                     'sadness':n_sadness, 
                     'anger': n_anger,
                     'anticipation':n_anticipation, 
                     'disgust':n_disgust}

for article in list_of_emotions_counter:
    print(article)
    correlator = list(article.keys())
    for elem in correlaction_dict: 
        if elem in correlator:
            correlaction_dict[elem].append(article[elem])
        elif elem not in correlator:
            correlaction_dict[elem].append(0)
        
#     print(n_trust, n_fear, n_surprise, n_joy, n_sadness, n_anger, n_anticipation, n_disgust)    
#     print('-----------------------------')    

df_emotion_levels = pd.DataFrame(list(zip(n_trust, n_fear, n_surprise, n_joy, n_sadness, n_anger, n_anticipation, n_disgust)), 
               columns =['n_trust', 'n_fear', 'n_surprise', 'n_joy', 'n_sadness', 'n_anger', 'n_anticipation', 'n_disgust'])

df_complete = pd.concat([df_articles, df_emotion_levels], axis=1)

df_complete.to_csv('larazon_emotions.csv')  
df_complete
# Out:
# Counter({'trust': 16, 'sadness': 6, 'anger': 5, 'fear': 3, 'joy': 2, 'disgust': 1, 'anticipation': 1})
# Counter({'trust': 25, 'sadness': 20, 'joy': 12, 'surprise': 11, 'fear': 10, 'anticipation': 4, 'anger': 1})
# Counter({'trust': 19, 'fear': 12, 'sadness': 5, 'anger': 5, 'surprise': 4, 'anticipation': 1, 'joy': 1})
# Counter({'trust': 15, 'fear': 4, 'anger': 3, 'surprise': 2, 'joy': 1, 'anticipation': 1, 'sadness': 1})
# Counter({'surprise': 3, 'fear': 2, 'sadness': 2, 'joy': 1, 'trust': 1})
# Counter({'trust': 5, 'sadness': 4, 'fear': 2, 'anticipation': 1, 'joy': 1, 'anger': 1, 'disgust': 1})
# Counter({'trust': 29, 'fear': 10, 'sadness': 9, 'surprise': 3, 'joy': 1, 'anger': 1})
# Counter({'trust': 11, 'joy': 7, 'sadness': 6, 'fear': 3, 'anticipation': 2})
# Counter({'sadness': 11, 'fear': 6, 'trust': 6, 'anger': 4, 'joy': 3, 'surprise': 2, 'anticipation': 1})
# Counter({'trust': 22, 'surprise': 5, 'fear': 5, 'joy': 3, 'anger': 3, 'sadness': 3, 'anticipation': 1})
# Counter({'trust': 10, 'surprise': 8, 'fear': 7, 'joy': 5, 'sadness': 5, 'anticipation': 1, 'anger': 1})
# Counter({'trust': 9, 'fear': 5, 'sadness': 4, 'joy': 3, 'surprise': 3, 'anger': 1})
#     Unnamed: 0                                       article_name  \
# 0            0  politica.php?n=45&-morales-pide-pausa-los-civi...
# 1            1  sociedad.php?n=15&-ministerio-publico-no-escla...
# 2            2  nacional.php?n=48&-afines-al-gobierno-agredier...
# 3            3  politica.php?n=53&-se-fractura-mision-de-oea-p...
# 4            4  sociedad.php?n=19&-6-aprehendidos-por-muerte-d...
# 5            5  nacional.php?n=16&-bloqueos-se-mantuvieron-en-...
# 6            6  politica.php?n=20&-piden-cumbre-nacional-para-...
# 7            7  sociedad.php?n=27&-sujeto-de-la-escopeta-dio-p...
# 8            8  nacional.php?n=46&-dinamitazos-y-violencia-des...
# 9            9  politica.php?n=77&-camacho-a-morales-vamos-a-s...
# 10          10  sociedad.php?n=29&-carlos-romero-asegura-que-h...
# 11          11  nacional.php?n=37&-iglesia-preocupada-por-crec...
#
#    article_date article_category  \
# 0     2019/11/1         politica
# 1     2019/11/1         sociedad
# 2     2019/11/1         nacional
# 3     2019/11/2         politica
# 4     2019/11/2         sociedad
# 5     2019/11/2         nacional
# 6     2019/11/3         politica
# 7     2019/11/3         sociedad
# 8     2019/11/3         nacional
# 9     2019/11/4         politica
# 10    2019/11/4         sociedad
# 11    2019/11/4         nacional
#
#                                         article_words  article_len  \
# 0   ['Después', 'de', 'dos', 'muertes', 'en', 'el'...          638
# 1   ['En', 'los', 'más', 'de', '13', 'años', 'de',...          887
# 2   ['Al', 'mediodía', 'de', 'ayer', 'un', 'numero...          468
# 3   ['La', 'misión', 'de', 'expertos', 'de', 'la',...          413
# 4   ['El', 'fiscal', 'departamental', 'de', 'Santa...          192
# 5   ['Pese', 'a', 'la', 'festividad', 'de', 'Todos...          304
# 6   ['El', 'analista', 'Iván', 'Arias,', 'señaló',...          723
# 7   ['Wilson', 'Rodríguez', 'Peralta,', 'el', 'suj...          373
# 8   ['Detonaciones', 'de', 'dinamitas', 'causadas'...          568
# 9   ['El', 'presidente', 'del', 'Comité', 'Cívico'...          577
# 10  ['El', 'ministro', 'de', 'Gobierno,', 'Carlos'...          562
# 11  ['La', 'Iglesia', 'Católica', 'advirtió', 'aye...          311
#
#                                           article_URL  n_trust  n_fear  \
# 0   https://www.eldiario.net/noticias/2019/2019_11...       16       3
# 1   https://www.eldiario.net/noticias/2019/2019_11...       25      10
# 2   https://www.eldiario.net/noticias/2019/2019_11...       19      12
# 3   https://www.eldiario.net/noticias/2019/2019_11...       15       4
# 4   https://www.eldiario.net/noticias/2019/2019_11...        1       2
# 5   https://www.eldiario.net/noticias/2019/2019_11...        5       2
# 6   https://www.eldiario.net/noticias/2019/2019_11...       29      10
# 7   https://www.eldiario.net/noticias/2019/2019_11...       11       3
# 8   https://www.eldiario.net/noticias/2019/2019_11...        6       6
# 9   https://www.eldiario.net/noticias/2019/2019_11...       22       5
# 10  https://www.eldiario.net/noticias/2019/2019_11...       10       7
# 11  https://www.eldiario.net/noticias/2019/2019_11...        9       5
#
#     n_surprise  n_joy  n_sadness  n_anger  n_anticipation  n_disgust
# 0            0      2          6        5               1          1
# 1           11     12         20        1               4          0
# 2            4      1          5        5               1          0
# 3            2      1          1        3               1          0
# 4            3      1          2        0               0          0
# 5            0      1          4        1               1          1
# 6            3      1          9        1               0          0
# 7            0      7          6        0               2          0
# 8            2      3         11        4               1          0
# 9            5      3          3        3               1          0
# 10           8      5          5        1               1          0
# 11           3      3          4        1               0          0
