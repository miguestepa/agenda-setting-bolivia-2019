# %%
import pandas as pd

# %%
name = 'twitter_bolivia_emotions_spanish'

# %%
file = pd.read_csv(f'{name}.csv', encoding ='utf-8')

# %%
df = pd.DataFrame(file)

# %%
df
# Out:
#         Unnamed: 0                                           hashtags  likes  \
# 0                0                                                 []      0
# 1                1                                                 []     12
# 2                2                                                 []      0
# 3                3                                                 []      1
# 4                4                                                 []      0
# ...            ...                                                ...    ...
# 158141      158141                                        ['Bolivia']     12
# 158142      158142                                       ['Nacional']      0
# 158143      158143                                                 []      0
# 158144      158144                                                 []      0
# 158145      158145  ['SebastianMoroFueElGolpe', 'JusticiaParaSenka...      4
#
# ...

# %%
indexNames = df[(df['n_trust'] == 0) & 
                (df['n_fear'] == 0) &
                (df['n_surprise'] == 0) &
                (df['n_joy'] == 0) &
                (df['n_sadness'] == 0) &
                (df['n_anger'] == 0) &
                (df['n_anticipation'] == 0) &
                (df['n_disgust'] == 0)
               ].index 

df.drop(indexNames , inplace=True)

df = df.drop(columns = ['Unnamed: 0'])

df = df.reset_index(drop=True)

# %%
df
# Out:
#                                                  hashtags  likes  \
# 0                                                      []     12
# 1                                                      []      0
# 2                                                      []      1
# 3                                                      []      0
# 4                                                 ['21F']      0
# ...                                                   ...    ...
# 126046         ['AygünNoticias', 'LaPaz', 'Comicios2020']      0
# 126047                                                 []      1
# 126048                                        ['Bolivia']     12
# 126049                                       ['Nacional']      0
# 126050  ['SebastianMoroFueElGolpe', 'JusticiaParaSenka...      4
#
#                                                     links  replies  retweets  \
# 0                                                      []        0         5
# ...

# %%
df.to_csv(f'{name}_cleaned.csv', encoding ='utf-8')
